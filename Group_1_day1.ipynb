# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
columns_to_keep = [
    "Year",                      
    "Month",                     
    "DayofMonth",                
    "DayOfWeek",                 
    "Airline",                   
    "Flight_Number_Marketing_Airline",  
    "Tail_Number",               
    "Origin",                    
    "Dest",                      
    "CRSDepTime",                
    "DepTime",                   
    "DepDelayMinutes",           
    "TaxiOut",                   
    "WheelsOff",                 
    "CRSElapsedTime",            
    "ActualElapsedTime",         
    "AirTime",                   
    "Distance",                  
    "WheelsOn",                  
    "TaxiIn",                    
    "CRSArrTime",                
    "ArrTime",                   
    "ArrDelayMinutes",          
    "Diverted",                  
    "Cancelled"
]

df = pd.read_csv("merged_output.csv", usecols=columns_to_keep)
df.head()
# Out:
#                   Airline Origin Dest  Cancelled  Diverted  CRSDepTime  \
# 0   SkyWest Airlines Inc.    ASE  DEN      False     False        1831
# 1   SkyWest Airlines Inc.    TYS  DEN      False     False        1605
# 2  American Airlines Inc.    LAX  OGG      False     False        1719
# 3  Southwest Airlines Co.    LAS  BWI      False     False        1515
# 4    Delta Air Lines Inc.    DTW  RDU      False     False         715
#
#    DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  ...  Month  DayofMonth  \
# 0   1826.0              0.0   1923.0              0.0  ...      3          19
# 1   1605.0              0.0   1812.0             35.0  ...      2          16
# 2   1714.0              0.0   2052.0              3.0  ...      1          18
# 3   1533.0             18.0   2302.0             27.0  ...      1          23
# 4    709.0              0.0    837.0              0.0  ...      7           1
#
# ...

# %%
list(df.columns)
# Out:
# ['Airline',
#  'Origin',
#  'Dest',
#  'Cancelled',
#  'Diverted',
#  'CRSDepTime',
#  'DepTime',
#  'DepDelayMinutes',
#  'ArrTime',
#  'ArrDelayMinutes',
#  'AirTime',
#  'CRSElapsedTime',
#  'ActualElapsedTime',
#  'Distance',
#  'Year',
#  'Month',
#  'DayofMonth',
#  'DayOfWeek',
#  'Flight_Number_Marketing_Airline',
#  'Tail_Number',
#  'TaxiOut',
#  'WheelsOff',
#  'WheelsOn',
#  'TaxiIn',
#  'CRSArrTime']

# %%
df.shape
# Out:
# (5516518, 25)

# %%
df.describe()
# Out:
#          CRSDepTime       DepTime  DepDelayMinutes       ArrTime  \
# count  5.516518e+06  5.357200e+06     5.357154e+06  5.352458e+06
# mean   1.325797e+03  1.328923e+03     1.314938e+01  1.467788e+03
# std    4.817694e+02  4.945816e+02     4.752003e+01  5.250559e+02
# min    1.000000e+00  1.000000e+00     0.000000e+00  1.000000e+00
# 25%    9.170000e+02  9.200000e+02     0.000000e+00  1.056000e+03
# 50%    1.319000e+03  1.322000e+03     0.000000e+00  1.504000e+03
# 75%    1.730000e+03  1.735000e+03     6.000000e+00  1.909000e+03
# max    2.359000e+03  2.400000e+03     3.072000e+03  2.400000e+03
#
#        ArrDelayMinutes       AirTime  CRSElapsedTime  ActualElapsedTime  \
# count     5.340950e+06  5.340950e+06    5.516515e+06       5.340950e+06
# mean      1.309064e+01  1.091673e+02    1.391385e+02       1.334586e+02
# std       4.710678e+01  6.893533e+01    7.055336e+01       7.061574e+01
# min       0.000000e+00  6.000000e+00   -2.920000e+02       1.500000e+01
# ...

# %%
df.head()
# Out:
#                   Airline Origin Dest  Cancelled  Diverted  CRSDepTime  \
# 0   SkyWest Airlines Inc.    ASE  DEN      False     False        1831
# 1   SkyWest Airlines Inc.    TYS  DEN      False     False        1605
# 2  American Airlines Inc.    LAX  OGG      False     False        1719
# 3  Southwest Airlines Co.    LAS  BWI      False     False        1515
# 4    Delta Air Lines Inc.    DTW  RDU      False     False         715
#
#    DepTime  DepDelayMinutes  ArrTime  ArrDelayMinutes  ...  Month  DayofMonth  \
# 0   1826.0              0.0   1923.0              0.0  ...      3          19
# 1   1605.0              0.0   1812.0             35.0  ...      2          16
# 2   1714.0              0.0   2052.0              3.0  ...      1          18
# 3   1533.0             18.0   2302.0             27.0  ...      1          23
# 4    709.0              0.0    837.0              0.0  ...      7           1
#
# ...

# %%
df
# Out:
#                         Airline Origin Dest  Cancelled  Diverted  CRSDepTime  \
# 0         SkyWest Airlines Inc.    ASE  DEN      False     False        1831
# 1         SkyWest Airlines Inc.    TYS  DEN      False     False        1605
# 2        American Airlines Inc.    LAX  OGG      False     False        1719
# 3        Southwest Airlines Co.    LAS  BWI      False     False        1515
# 4          Delta Air Lines Inc.    DTW  RDU      False     False         715
# ...                         ...    ...  ...        ...       ...         ...
# 5516513   SkyWest Airlines Inc.    MSP  OMA      False     False        1528
# 5516514  Southwest Airlines Co.    MCO  ATL      False     False         635
# 5516515   United Air Lines Inc.    CLE  PHX      False     False        1015
# 5516516   United Air Lines Inc.    SJU  IAH      False     False        1630
# 5516517  Frontier Airlines Inc.    LAS  IND      False     False        1138
#
# ...

# %%
airlines=pd.read_csv('Airlines.csv')
airlines.head()
# Out:
#   Code                    Description
# 0  02Q                  Titan Airways
# 1  04Q             Tradewind Aviation
# 2  05Q            Comlux Aviation, AG
# 3  06Q  Master Top Linhas Aereas Ltd.
# 4  07Q            Flair Airlines Ltd.

# %%
airlinecompanies=airlines.set_index('Code')['Description'].to_dict()
airlinecompanies
# Out:
# {'02Q': 'Titan Airways',
#  '04Q': 'Tradewind Aviation',
#  '05Q': 'Comlux Aviation, AG',
#  '06Q': 'Master Top Linhas Aereas Ltd.',
#  '07Q': 'Flair Airlines Ltd.',
#  '09Q': 'Swift Air, LLC',
#  '0BQ': 'DCA',
#  '0CQ': 'ACM AIR CHARTER GmbH',
#  '0GQ': 'Inter Island Airways, d/b/a Inter Island Air',
#  '0HQ': 'Polar Airlines de Mexico d/b/a Nova Air',
#  '0J': 'JetClub AG',
#  '0JQ': 'Vision Airlines',
#  '0LQ': 'Metropix UK, LLP.',
#  '0MQ': 'Multi-Aero, Inc. d/b/a Air Choice One',
#  '0OQ': 'Open Skies',
#  '0Q': 'Flying Service N.V.',
#  '0QQ': 'TAG Aviation (UK) Ltd.',
#  '0RQ': 'TAG Aviation Espana S.L.',
#  '0TQ': 'Corporatejets, XXI',
#  '0UQ': 'Comlux Malta, Ltd.',
#  '0VQ': 'Ocean Sky (UK) Limited',
#  '0WQ': 'Avjet Corporation',
#  '0YQ': 'Comlux Malta Ltd.',
#  '10Q': 'Swiss Air Ambulance',
#  '12Q': 'Unijet',
#  '13Q': 'Chartright Air Inc.',
#  '14Q': 'London Air Services Limited',
#  '15Q': 'Air Alsie A/S',
#  '16': 'PSA Airlines Inc.',
#  '17': 'Piedmont Airlines',
# ...

# %%
flightsinfo=df

# %%
delay_type = lambda x:((0,1)[x > 5],2)[x > 45]
flightsinfo['DELAY_LEVEL'] = flightsinfo['DepDelayMinutes'].apply(delay_type)

fig = plt.figure(1, figsize=(10,7))
ax = sns.countplot(x="Airline", hue='DELAY_LEVEL', data=flightsinfo, palette= ["#00FF00","#FFA500","#FF0000"])

labels = ax.get_xticklabels()
ax.set_xticklabels(labels)
plt.setp(ax.get_yticklabels(), fontsize=12, weight = 'normal', rotation = 90);
plt.setp(ax.get_xticklabels(), fontsize=12, weight = 'normal', rotation = 90);
ax.xaxis.label.set_visible(False)
plt.ylabel('No. of Flights', fontsize=16, weight = 'bold', labelpad=10)

L = plt.legend()
L.get_texts()[0].set_text('on time (t < 5 min)')
L.get_texts()[1].set_text('small delay (5 < t < 45 min)')
L.get_texts()[2].set_text('large delay (t > 45 min)')
plt.show()
# Out:
# C:\Users\dewang\AppData\Local\Temp\ipykernel_12988\3100909001.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels)

# %%
# Drawing a Yellow Bar Chart for Departure Delay
# Drawing a Blue 'X' Pattern for Arrival Delay
# Fixing Airline Names on X-axis




fig = plt.figure(1, figsize=(11,6))
ax = sns.barplot(x="Airline", y="DepDelayMinutes", data=flightsinfo, color="orange", ci=None)
ax = sns.barplot(x="Airline",y="ArrDelayMinutes",  data=flightsinfo, color="b", hatch = 'X',
                 alpha = 0.0, ci=None)
labels = ax.get_xticklabels()
ax.set_xticklabels(labels,rotation = 90)
ax.xaxis.label.set_visible(False)
plt.ylabel('Mean delay - Yellow (Departure), X (Arrival)',
           fontsize=14, weight = 'bold', labelpad=10);
